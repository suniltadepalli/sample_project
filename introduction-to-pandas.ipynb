# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series is 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "Green"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %%
# DataFrame is 2-dimensional

# %%
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  Green

# %%
# Import data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Odometer (KM)"].sum()
# Out:
# 786014

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
#  ## Viewing and selecting data

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and .iloc
animals = pd.Series(["cat","dog","panda","tiger","python"], index=[0,3,9,8,3])

# %%
animals
# Out:
# 0       cat
# 3       dog
# 9     panda
# 8     tiger
# 3    python
# dtype: object

# %%
# loc refers to index
animals.loc[3]
# Out:
# 3       dog
# 3    python
# dtype: object

# %%
animals.loc[9]
# Out:
# 'panda'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'tiger'

# %%
# Give us items upto position 3

# %%
animals.iloc[:3]
# Out:
# 0      cat
# 3      dog
# 9    panda
# dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Groupby
car_sales.groupby(["Make"]).mean(["Doors"])
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Groupby
car_sales.groupby(["Colour"]).mean(["Doors"])
# Out:
#         Odometer (KM)     Doors
# Colour
# Black    11179.000000  5.000000
# Blue     44328.333333  3.666667
# Green    99213.000000  4.000000
# Red      87899.000000  4.000000
# White   113684.500000  4.000000

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# /var/folders/x1/_kzzqdc56312nybjr5k6sj6c0000gn/T/ipykernel_48373/2312081839.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].dtype
# Out:
# dtype('int64')

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$,]', '', regex=True).str.split('.').str[0].astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/suniltadepalli/training/PycharmProjects/sample_project/introduction-to-pandas.ipynb Cell 48 line 1
# ----> <a href='vscode-notebook-cell:/Users/suniltadepalli/training/PycharmProjects/sample_project/introduction-to-pandas.ipynb#X65sZmlsZQ%3D%3D?line=0'>1</a> car_sales['Price'] = car_sales['Price'].str.replace('[\$,]', '', regex=True).str.split('.').str[0].astype(int)
#
# File ~/miniconda3/envs/islp/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].astype(str)

# %%
car_sales["Make"].dtype
# Out:
# dtype('O')

# %%
car_sales["Make"] = car_sales["Make"].astype(str)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
# Column from series
seats_column = pd.Series([5,5,5,5,5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    5.0
# 6   honda   Blue          45698      4   7500    5.0
# 7   honda   Blue          54738      4   7000    5.0
# 8  toyota  White          60000      4   6250    5.0
# 9  nissan  White          31600      4   9700    5.0

# %%
# Column from python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8,7, 4.7, 7.6, 8.7, 3.0]
car_sales["Fuel Per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Per 100KM
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.0
# 5  toyota  Green          99213      4   4500    5.0             7.0
# 6   honda   Blue          45698      4   7500    5.0             4.7
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel Per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.0
# 5  toyota  Green          99213      4   4500    5.0             7.0
# 6   honda   Blue          45698      4   7500    5.0             4.7
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        17047.600
# 5         6944.910
# 6         2147.806
# 7         4160.088
# 8         5220.000
# ...

# %%
car_sales["Number of wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.0
# 5  toyota  Green          99213      4   4500    5.0             7.0
# 6   honda   Blue          45698      4   7500    5.0             4.7
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Total fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# 3         1073.184                 4
# ...

# %%
car_sales["Passed Road Safety"] = True
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int64
# Seats                 float64
# Fuel Per 100KM        float64
# Total fuel used       float64
# Number of wheels        int64
# Passed Road Saftey       bool
# Passed Road Safety       bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.0
# 5  toyota  Green          99213      4   4500    5.0             7.0
# 6   honda   Blue          45698      4   7500    5.0             4.7
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Total fuel used  Number of wheels  Passed Road Saftey  Passed Road Safety
# 0        11253.225                 4                True                True
# ...

# %%
car_sales = car_sales.drop("Passed Road Saftey", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.0
# 5  toyota  Green          99213      4   4500    5.0             7.0
# 6   honda   Blue          45698      4   7500    5.0             4.7
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             3.0
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
car_sales = car_sales.sample(frac=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Per 100KM  \
# 9  nissan  White          31600      4   9700    5.0             3.0
# 4  nissan  White         213095      4   3500    5.0             8.0
# 0  toyota  White         150043      4   4000    5.0             7.5
# 6   honda   Blue          45698      4   7500    5.0             4.7
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 7   honda   Blue          54738      4   7000    5.0             7.6
# 8  toyota  White          60000      4   6250    5.0             8.7
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 5  toyota  Green          99213      4   4500    5.0             7.0
# 1   honda    Red          87899      4   5000    5.0             9.2
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 9          948.000                 4                True
# 4        17047.600                 4                True
# ...

# %%
# Only select 20% of the data

# %%
car_sales_shuffled_20pc = car_sales.sample(frac=0.2)

# %%
car_sales_shuffled_20pc
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Per 100KM  \
# 9  nissan  White          31600      4   9700    5.0             3.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 9          948.000                 4                True
# 3         1073.184                 4                True

# %%
car_sales.reset_index(drop=True)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Per 100KM  \
# 0  nissan  White          31600      4   9700    5.0             3.0
# 1  nissan  White         213095      4   3500    5.0             8.0
# 2  toyota  White         150043      4   4000    5.0             7.5
# 3   honda   Blue          45698      4   7500    5.0             4.7
# 4     bmw  Black          11179      5  22000    5.0             9.6
# 5   honda   Blue          54738      4   7000    5.0             7.6
# 6  toyota  White          60000      4   6250    5.0             8.7
# 7  toyota   Blue          32549      3   7000    5.0             5.0
# 8  toyota  Green          99213      4   4500    5.0             7.0
# 9   honda    Red          87899      4   5000    5.0             9.2
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 0          948.000                 4                True
# 1        17047.600                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Per 100KM  \
# 9  nissan  White      19750.000      4   9700    5.0             3.0
# 4  nissan  White     133184.375      4   3500    5.0             8.0
# 0  toyota  White      93776.875      4   4000    5.0             7.5
# 6   honda   Blue      28561.250      4   7500    5.0             4.7
# 3     bmw  Black       6986.875      5  22000    5.0             9.6
# 7   honda   Blue      34211.250      4   7000    5.0             7.6
# 8  toyota  White      37500.000      4   6250    5.0             8.7
# 2  toyota   Blue      20343.125      3   7000    5.0             5.0
# 5  toyota  Green      62008.125      4   4500    5.0             7.0
# 1   honda    Red      54936.875      4   5000    5.0             9.2
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 9          948.000                 4                True
# 4        17047.600                 4                True
# ...
